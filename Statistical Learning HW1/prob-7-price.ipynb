# %% [markdown]
# statistical learning #housing price#

# %%
#correlation maatrix method1
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/Users/amirhossein/Desktop/sharif/third semester/statistical learning/HW1 3/housing.data' ,header=None, sep='\s+')
b=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
i=0
for a in b:
    data[a]=data[i]
    i+=1

for i in range(14):
    data.pop(i)
y=data.pop('MEDV')
corr = data.corr()

mask = np.zeros_like(corr)
# mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    fig, ax = plt.subplots(figsize=(15, 12));
    
    sns.heatmap(
        corr,
        ax=ax,
        annot=True,
        square=True
    );

# %%
#correlation maatrix method2
import sys
import numpy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/Users/amirhossein/Desktop/sharif/third semester/statistical learning/HW1 3/housing.data' ,header=None, sep='\s+')
b=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
i=0
for a in b:
    data[a]=data[i]
    i+=1

for i in range(14):
    data.pop(i)
y=data.pop('MEDV')
des=data.describe().T
normalized_Data=(data-des['mean'])/des['std']
# normalized_Data['ones']=np.ones(506)
normalized_Data=pd.DataFrame(normalized_Data,columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])
X=normalized_Data
cova=np.dot(X.T,X)
cova=cova/506
b=plt.matshow(cova )
plt.colorbar(b)
plt.show()
print(np.asmatrix(cova))
a=plt.pcolor(cova,cmap='Reds_r')
plt.colorbar(a)
plt.show()
# Out:
# [[ 0.99802372 -0.20007304  0.40577989 -0.05578112  0.42013975 -0.21881341
#    0.35203715 -0.37891975  0.62426897  0.5816126   0.28937256 -0.38430295
#    0.45472104]
#  [-0.20007304  0.99802372 -0.53277319 -0.04261234 -0.51558275  0.31137401
#   -0.56841177  0.66309516 -0.31133133 -0.31394166 -0.39090448  0.17517344
#   -0.41217838]
#  [ 0.40577989 -0.53277319  0.99802372  0.06281364  0.76214225 -0.39090179
#    0.64350425 -0.70662773  0.59395313  0.71933575  0.38249015 -0.35627105
#    0.60260644]
#  [-0.05578112 -0.04261234  0.06281364  0.99802372  0.09102256  0.09107089
#    0.08634679 -0.09897978 -0.00735368 -0.03551619 -0.12127503  0.04869207
#   -0.05382272]
#  [ 0.42013975 -0.51558275  0.76214225  0.09102256  0.99802372 -0.30159098
#    0.73002451 -0.7677099   0.61023218  0.666703    0.18855929 -0.37929955
#    0.58971118]
#  [-0.21881341  0.31137401 -0.39090179  0.09107089 -0.30159098  0.99802372
#   -0.2397901   0.20484059 -0.20943195 -0.29147066 -0.35479892  0.12781554
# ...

# %%
#correlation maatrix method3
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/Users/amirhossein/Desktop/sharif/third semester/statistical learning/HW1 3/housing.data' ,header=None, sep='\s+')
b=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
i=0
for a in b:
    data[a]=data[i]
    i+=1

for i in range(14):
    data.pop(i)
y=data.pop('MEDV')
des=data.describe().T
normalized_Data=(data-des['mean'])/des['std']
normalized_Data=pd.DataFrame(normalized_Data,columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])
X=normalized_Data
co=np.matmul(np.transpose(X),X)
co=co/506
print(co)
a=plt.pcolor(co,cmap='Reds_r')
plt.colorbar(a)
# Out:
# [[ 0.99802372 -0.20007304  0.40577989 -0.05578112  0.42013975 -0.21881341
#    0.35203715 -0.37891975  0.62426897  0.5816126   0.28937256 -0.38430295
#    0.45472104]
#  [-0.20007304  0.99802372 -0.53277319 -0.04261234 -0.51558275  0.31137401
#   -0.56841177  0.66309516 -0.31133133 -0.31394166 -0.39090448  0.17517344
#   -0.41217838]
#  [ 0.40577989 -0.53277319  0.99802372  0.06281364  0.76214225 -0.39090179
#    0.64350425 -0.70662773  0.59395313  0.71933575  0.38249015 -0.35627105
#    0.60260644]
#  [-0.05578112 -0.04261234  0.06281364  0.99802372  0.09102256  0.09107089
#    0.08634679 -0.09897978 -0.00735368 -0.03551619 -0.12127503  0.04869207
#   -0.05382272]
#  [ 0.42013975 -0.51558275  0.76214225  0.09102256  0.99802372 -0.30159098
#    0.73002451 -0.7677099   0.61023218  0.666703    0.18855929 -0.37929955
#    0.58971118]
#  [-0.21881341  0.31137401 -0.39090179  0.09107089 -0.30159098  0.99802372
#   -0.2397901   0.20484059 -0.20943195 -0.29147066 -0.35479892  0.12781554
# ...

# %%
#part1 visualization of data
sns.pairplot(X, diag_kind="kde")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
data=pd.read_csv('/Users/amirhossein/Desktop/sharif/third semester/statistical learning/HW1 3/housing.data' ,header=None, sep='\s+')
b=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
i=0
for a in b:
    data[a]=data[i]
    i+=1
for i in range(14):
    data.pop(i)
des=data.describe().T
data_norme3=(data-des['mean'])/des['std']
y=data_norme3.pop('MEDV')
X_train, X_test, y_train, y_test = train_test_split(
    data_norme3,
    y,
    test_size=0.3,random_state=0)
reg1 = LinearRegression().fit(X_train, y_train)
print('regression score is',reg1.score(X_train, y_train))
y_pred_test=reg1.predict(X_test)
y_pred_train=reg1.predict(X_train)
print('mean square error for train',mean_squared_error(y_train,y_pred_train))
print('mean square error for test',mean_squared_error(y_test,y_pred_test))
print('coefficients for linear regresion are',reg1.coef_)
print('intercept is',reg1.intercept_)
x=reg1.coef_
y=reg1.intercept_
x=pd.DataFrame(x)
x['corresponding feature']=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']
# Out:
# ('regression score is', 0.7645451026942549)
# ('mean square error for train', 0.23594979171921113)
# ('mean square error for test', 0.3215157723496526)
# ('coefficients for linear regresion are', array([-0.11345494,  0.11276007,  0.00846006,  0.06935244, -0.20450349,
#         0.29481534, -0.03056082, -0.34349212,  0.22924672, -0.20288752,
#        -0.23957313,  0.06764365, -0.37792619]))
# ('intercept is', -0.008317428965594752)

# %%
x.rename(columns={0:'coefficents'
                 }, 
                 inplace=True)

# %%
ne=pd.DataFrame({'coefficents':[y],
                'corresponding feature':'intercept'})

# %%
x.append(ne)
# Out:
#     coefficents corresponding feature
# 0     -0.113455                  CRIM
# 1      0.112760                    ZN
# 2      0.008460                 INDUS
# 3      0.069352                  CHAS
# 4     -0.204503                   NOX
# 5      0.294815                    RM
# 6     -0.030561                   AGE
# 7     -0.343492                   DIS
# 8      0.229247                   RAD
# 9     -0.202888                   TAX
# 10    -0.239573               PTRATIO
# 11     0.067644                     B
# 12    -0.377926                 LSTAT
# 0     -0.008317             intercept
